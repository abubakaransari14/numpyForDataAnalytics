# %% [markdown]
# Numpy Constants

# %%
import numpy as np

radius = 2
circumference = 2 * np.pi * radius
print(circumference)
# Out:
# 12.566370614359172

# %%
y = np.e

print(y)
# Out:
# 2.718281828459045
